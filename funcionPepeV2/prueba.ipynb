# %% [markdown]
# <div style="display: flex; justify-content: center;">
#     <img src="ima/piesgrd.jpg" style="border-radius: 20px; width: 75%;">
# </div>

# %%
import pandas as pd 
from funciones_juntas import *

# %%
#importamos distintos df para hacer las pruebas

df_casas = pd.read_csv("./dataframe/ejemplo_housing.csv") 

df_practica = pd.read_csv("./dataframe/obligatoria_hard.csv", delimiter="|") 

df_vinos = pd.read_csv("./dataframe/wines_dataset.csv", delimiter="|")

# %%
df_casas. head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_practica.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO  LSTAT  MEDV
# 0     15.3   4.98  24.0
# 1     17.8   9.14  21.6
# 2     17.8   4.03  34.7
# 3     18.7   2.94  33.4
# 4     18.7   5.33  36.2

# %%
df_vinos.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.5              0.21         0.26            9.25      0.034
# 1            8.3              0.16         0.37            7.90      0.025
# 2            6.8              0.18         0.38            1.40      0.038
# 3            6.1              0.26         0.25            2.90      0.047
# 4            7.5              0.63         0.27            2.00      0.083
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 73.0                 142.0  0.99450  3.05       0.37
# 1                 38.0                 107.0  0.99306  2.93       0.37
# 2                 35.0                 111.0  0.99180  3.32       0.59
# 3                289.0                 440.0  0.99314  3.44       0.64
# 4                 17.0                  91.0  0.99616  3.26       0.58
#
#    alcohol  quality  class
# 0     11.4        6  white
# 1     11.9        6  white
# ...

# %% [markdown]
# ### FUNCIÓN DESCRIBE_DF

# %%
describe_df(df_casas)
# Out:
#               longitude latitude housing_median_age total_rooms  \
# DATE_TYPE       float64  float64            float64     float64
# MISSINGS (%)        0.0      0.0                0.0         0.0
# UNIQUE_VALUES       844      861                 52        5911
# CARDIN (%)         4.13     4.21               0.25       28.93
#
#               total_bedrooms population households median_income  \
# DATE_TYPE            float64    float64    float64       float64
# MISSINGS (%)             0.0        0.0        0.0           0.0
# UNIQUE_VALUES           1923       3879       1809         12825
# CARDIN (%)              9.41      18.98       8.85         62.77
#
#               median_house_value ocean_proximity
# DATE_TYPE                float64          object
# MISSINGS (%)                 0.0             0.0
# UNIQUE_VALUES               3833               5
# CARDIN (%)                 18.76            0.02

# %% [markdown]
# ### FUNCION TIPIFICA_VARIABLES

# %%
tipifica_variables(df_casas, 10, 20.0)
# Out:
#       nombre_variable      tipo_sugerido
# 0           longitude  Numérica Discreta
# 1            latitude  Numérica Discreta
# 2  housing_median_age  Numérica Discreta
# 3         total_rooms  Numérica Continua
# 4      total_bedrooms  Numérica Discreta
# 5          population  Numérica Discreta
# 6          households  Numérica Discreta
# 7       median_income  Numérica Continua
# 8  median_house_value  Numérica Discreta
# 9     ocean_proximity         Categórica

# %% [markdown]
# ### FUNCIÓN GET_FEATURES_NUM_REGRESSION

# %%
features_numericas = get_features_num_regression(df_casas, 'median_house_value', 0.05)

print("Las columnas numéricas cuya correlación con el target es superior a lo que necesitamos son:", features_numericas)
print("Sí, la columna target sale aquí, lo sé.")
# Out:
# Las columnas numéricas cuya correlación con el target es superior a lo que necesitamos son: ['latitude', 'housing_median_age', 'total_rooms', 'households', 'median_income', 'median_house_value']
# Sí, la columna target sale aquí, lo sé.

# %% [markdown]
# ### FUNCIÓN GET_FEATURES_NUM_REGRESSIONV2

# %%
features_numericasv2 = get_features_num_regression_V2(df_casas, 'median_house_value', 0.05)

#print("Las columnas numéricas cuya correlación con el target es superior a lo que necesitamos son:", features_numericas)
#print("Sí, la columna target sale aquí, lo sé.")
# Out:
# Las columnas numéricas cuya correlación con el target es superior a lo que necesitamos son:

# %% [markdown]
# ### FUNCIÓN PLOT_FEATURES_NUM_REGRESSION

# %%
plot_features_num_regression(df_practica, target_col='MEDV', columns=[], umbral_corr=0.05)
# Out:
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'CHAS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'LSTAT']

# %% [markdown]
# ### FUNCIÓN GET_FEATURES_CAT_REGRESSION

# %%
get_features_cat_regression(df_casas, 'median_house_value', pvalue=0.05)
# Out:
# ['ocean_proximity']

# %% [markdown]
# ### FUNCION PLOT_FEATURES_CAT_REGRESSION

# %%
plot_features_cat_regression(df_vinos, target_col="quality", columns=[], pvalue=0.05, with_individual_plot=False)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ['class']
